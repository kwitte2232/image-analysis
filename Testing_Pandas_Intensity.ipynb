# %%
import re
import os
import shutil
import numpy as np

# %%
directory = "/Users/Kristen/Desktop/06212016_WYK8440_Scaled_plusG1"

# %%
experiments = ["03", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "14", "15", "16"]

for num in experiments:
    curr_expt = "Exp"+num
    new_dir = "Regions"+num
    for dir_name, field_dir, dir_files in os.walk(directory):
        if dir_name == directory:
            for files in dir_files:
                if re.search(curr_expt, files):
                    shutil.move(dir_name+"/"+files, dir_name+"/"+new_dir+"/"+files)

# %%
for num in experiments:
    curr_dir = "Regions"+num+"/"
    for dir_name, regions_dir, dir_files in os.walk(directory):
        for regions_name in regions_dir:
            if (dir_name+"/"+regions_name+"/") == (dir_name+"/"+curr_dir):
                for root, dirs, files in os.walk(dir_name+"/"+regions_name+"/"):
                    for f in files:
                        file_name = list(f)
                        if file_name[10] != ".":
                            file_name.insert(8,"0")
                            new_name = "".join(file_name)
                            os.rename(dir_name+"/"+curr_dir+f, dir_name+"/"+curr_dir+new_name)
# Out:
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp03tar01.rgn
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp03tar02.rgn
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp03tar03.rgn
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp03tar04.rgn
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp03tar05.rgn
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp03tar06.rgn
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp03tar07.rgn
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp03tar08.rgn
# ['E', 'x', 'p', '0', '3', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp03tar09.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp04tar01.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp04tar02.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp04tar03.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp04tar04.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp04tar05.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp04tar06.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp04tar07.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp04tar08.rgn
# ['E', 'x', 'p', '0', '4', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp04tar09.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp05tar01.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp05tar02.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp05tar03.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp05tar04.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp05tar05.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp05tar06.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp05tar07.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp05tar08.rgn
# ['E', 'x', 'p', '0', '5', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp05tar09.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp06tar01.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp06tar02.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp06tar03.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp06tar04.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp06tar05.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp06tar06.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp06tar07.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp06tar08.rgn
# ['E', 'x', 'p', '0', '6', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp06tar09.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp07tar01.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp07tar02.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp07tar03.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp07tar04.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp07tar05.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp07tar06.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp07tar07.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp07tar08.rgn
# ['E', 'x', 'p', '0', '7', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp07tar09.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp08tar01.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp08tar02.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp08tar03.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp08tar04.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp08tar05.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp08tar06.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp08tar07.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp08tar08.rgn
# ['E', 'x', 'p', '0', '8', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp08tar09.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp09tar01.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp09tar02.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp09tar03.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp09tar04.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp09tar05.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp09tar06.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp09tar07.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp09tar08.rgn
# ['E', 'x', 'p', '0', '9', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp09tar09.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp10tar01.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp10tar02.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp10tar03.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp10tar04.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp10tar05.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp10tar06.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp10tar07.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp10tar08.rgn
# ['E', 'x', 'p', '1', '0', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp10tar09.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp11tar01.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp11tar02.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp11tar03.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp11tar04.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp11tar05.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp11tar06.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp11tar07.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp11tar08.rgn
# ['E', 'x', 'p', '1', '1', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp11tar09.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp12tar01.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp12tar02.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp12tar03.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp12tar04.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp12tar05.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp12tar06.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp12tar07.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp12tar08.rgn
# ['E', 'x', 'p', '1', '2', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp12tar09.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp13tar01.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp13tar02.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp13tar03.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp13tar04.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp13tar05.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp13tar06.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp13tar07.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp13tar08.rgn
# ['E', 'x', 'p', '1', '3', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp13tar09.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp14tar01.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp14tar02.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp14tar03.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp14tar04.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp14tar05.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp14tar06.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp14tar07.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp14tar08.rgn
# ['E', 'x', 'p', '1', '4', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp14tar09.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp15tar01.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp15tar02.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp15tar03.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp15tar04.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp15tar05.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp15tar06.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp15tar07.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp15tar08.rgn
# ['E', 'x', 'p', '1', '5', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp15tar09.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '1', '.', 'r', 'g', 'n']
# Exp16tar01.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '1', '0', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '1', '1', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '1', '2', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '1', '3', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '1', '4', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '1', '5', '.', 'r', 'g', 'n']
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '2', '.', 'r', 'g', 'n']
# Exp16tar02.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '3', '.', 'r', 'g', 'n']
# Exp16tar03.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '4', '.', 'r', 'g', 'n']
# Exp16tar04.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '5', '.', 'r', 'g', 'n']
# Exp16tar05.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '6', '.', 'r', 'g', 'n']
# Exp16tar06.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '7', '.', 'r', 'g', 'n']
# Exp16tar07.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '8', '.', 'r', 'g', 'n']
# Exp16tar08.rgn
# ['E', 'x', 'p', '1', '6', 't', 'a', 'r', '9', '.', 'r', 'g', 'n']
# Exp16tar09.rgn

# %%
import pandas as pd
filename = "/Users/Kristen/Desktop/06212016_WYK8440_Scaled_plusG1/5_seconds_1/processedImages/Cell_1/intensities.csv" 
data = pd.read_csv(filename)

# %%
data
# Out:
#          Mean_ROI_0  Max_ROI_0   Mean_ROI_1  Max_ROI_1   Mean_ROI_2  Max_ROI_2
# 0    1  1167.428571       1264  1174.333333       1230  1160.904762       1264
# 1    2  1158.952381       1220  1169.380952       1230  1163.952381       1214
# 2    3  1166.190476       1211  1182.523810       1295  1170.047619       1215
# 3    4  1166.666667       1216  1164.142857       1203  1172.666667       1222
# 4    5  1157.571429       1207  1163.380952       1207  1162.333333       1210
# 5    6  1168.523810       1243  1177.809524       1243  1164.333333       1243
# 6    7  1165.571429       1218  1181.000000       1236  1166.571429       1247
# 7    8  1177.428571       1214  1182.333333       1230  1175.809524       1217
# 8    9  1164.904762       1203  1184.000000       1254  1163.428571       1249
# 9   10  1173.904762       1210  1175.190476       1222  1174.095238       1228
# 10  11  1179.333333       1228  1167.619048       1227  1188.761905       1247
# 11  12  1169.857143       1227  1177.238095       1227  1174.190476       1208
# 12  13  1172.000000       1231  1176.904762       1231  1173.000000       1239
# 13  14  1159.047619       1247  1169.904762       1217  1167.857143       1247
# 14  15  1157.095238       1219  1165.428571       1239  1167.857143       1253

# %%
mean_data = data[["Mean_ROI_0", "Mean_ROI_1", "Mean_ROI_2"]]

# %%
max_data = data[["Max_ROI_0", "Max_ROI_1", "Max_ROI_2"]]

# %% [markdown]
# max_data

# %%
max_data
# Out:
#     Max_ROI_0  Max_ROI_1  Max_ROI_2
# 0        1264       1230       1264
# 1        1220       1230       1214
# 2        1211       1295       1215
# 3        1216       1203       1222
# 4        1207       1207       1210
# 5        1243       1243       1243
# 6        1218       1236       1247
# 7        1214       1230       1217
# 8        1203       1254       1249
# 9        1210       1222       1228
# 10       1228       1227       1247
# 11       1227       1227       1208
# 12       1231       1231       1239
# 13       1247       1217       1247
# 14       1219       1239       1253

# %%
max_data_array = np.asarray(max_data)

# %%
max_data_array
# Out:
# array([[1264, 1230, 1264],
#        [1220, 1230, 1214],
#        [1211, 1295, 1215],
#        [1216, 1203, 1222],
#        [1207, 1207, 1210],
#        [1243, 1243, 1243],
#        [1218, 1236, 1247],
#        [1214, 1230, 1217],
#        [1203, 1254, 1249],
#        [1210, 1222, 1228],
#        [1228, 1227, 1247],
#        [1227, 1227, 1208],
#        [1231, 1231, 1239],
#        [1247, 1217, 1247],
#        [1219, 1239, 1253]])

# %% [markdown]
# Build a large pd data frame as follows

# %% [markdown]
# Cell ID/ Cell Cycle Stage/ Num Pulses/ Target Pre Mean/ Target Post Mean/ Target Pre Max/ Target Post Max //
#     Daughter Pre Mean/ Daughter Post Mean/ Daughter Pre Max/ Daughter Pre Post

# %% [markdown]
# All intensity data will be held as multi-dimensional numpy arrays

# %% [markdown]
# Ex: Mean Pre np.arry = [[1a,1b,1c],[2a,2b,2c],[3a,3b,3c],[4a,4b,4c]]

# %% [markdown]
# Cell cycle stage may convert to daughter cell size and then during the data processing add a column that has cellcycle stage (which would then need to be convertd to a numerical value). this will depend on how the data is acquired from the scripts that process the imaging data
